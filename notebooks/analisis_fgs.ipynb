# %% [markdown]
# # Análisis de los Grupos Funcionales

# %%
import sys
import os
import pandas as pd

# Subimos un nivel para estar en la carpeta nuevo"Nuevo"
os.chdir("../")  

sys.path.append(os.getcwd())

from scripts.analisis_fgs import (
    calcular_estadisticas_fgs, 
    plot_top_20_fgs, 
    calcular_estadisticas_aromaticos_heteroatomos, 
    calcular_estadisticas_heteroatomos, 
    visualizar_coocurrencia_top_20_fgs
)

# %% [markdown]
# # Resultados PDB

# %%
# Cargar Dataset de PDB
fgs_pdb = pd.read_csv("./data/processed/fgs_pdb.csv")

# Llamadas a la función calcular_estadisticas_fgs para base de datos de PDB
tabla1_pdb = calcular_estadisticas_fgs(fgs_pdb)
tabla1_pdb
# Out:
#      n  Total FGs  FGs por mol  FGs binarios  FGs binarios por mol  \
# 0  483       2749     5.691511          1881               3.89441
#
#    FGs únicos  FGs únicos por mol
# 0         128             0.26501

# %%
# Llamadas a la función plot_top_20_fgs para base de datos de PDB
plot_top_20_fgs(fgs_pdb)

# %%
# Llamadas a la función calcular_estadisticas_aromaticos_heteroatomos para base de datos de PDB
tabla2_pdb = calcular_estadisticas_aromaticos_heteroatomos(fgs_pdb)
tabla2_pdb
# Out:
#    Ar FGs (bin) / mol  # Ar FGs (un)  Ar FGs (un) / mol  Het FGs (bin) / mol  \
# 0            1.743271            483                1.0             5.515528
#
#    # Het FGs (un)  Het FGs (un) / mol
# 0            1808            3.743271

# %%
# Llamadas a la función calcular_estadisticas_heteroatomos para base de datos de PDB
tabla3_pdb = calcular_estadisticas_heteroatomos(fgs_pdb)
tabla3_pdb
# Out:
#    O FGs (bin) / mol  Frac O FGs (un)  N FGs (bin) / mol  Frac N FGs (un)  \
# 0           2.679089         2.031056           2.610766         1.770186
#
#    S FGs (bin) / mol  Frac S FGs (un)  P FGs (bin) / mol  Frac P FGs (un)  \
# 0           0.217391          0.20911           0.016563         0.012422
#
#    X FGs (bin) / mol  Frac X FGs (un)
# 0           0.726708         0.416149

# %%
# Llamadas a la función visualizar_coocurrencia_top_20_fgs para base de datos de PDB
visualizar_coocurrencia_top_20_fgs(fgs_pdb)

# %% [markdown]
# # Resultados DrugBank

# %%
# Cargar Dataset de DrugBank
fgs_drugbank = pd.read_csv("./data/processed/fgs_drugbank.csv")

# Llamadas a la función para base de datos de DrugBank
tabla1_drugbank = calcular_estadisticas_fgs(fgs_drugbank)
tabla1_drugbank
# Out:
#       n  Total FGs  FGs por mol  FGs binarios  FGs binarios por mol  \
# 0  1306       6841     5.238132          4691              3.591884
#
#    FGs únicos  FGs únicos por mol
# 0         234            0.179173

# %%
# Llamadas a la función plot_top_20_fgs para base de datos de DrugBank
plot_top_20_fgs(fgs_drugbank)

# %%
# Llamadas a la función calcular_estadisticas_aromaticos_heteroatomos para base de datos de DrugBank
tabla2_drugbank = calcular_estadisticas_aromaticos_heteroatomos(fgs_drugbank)
tabla2_drugbank
# Out:
#    Ar FGs (bin) / mol  # Ar FGs (un)  Ar FGs (un) / mol  Het FGs (bin) / mol  \
# 0            1.378254           1049           0.803216             5.077335
#
#    # Het FGs (un)  Het FGs (un) / mol
# 0            4527            3.466309

# %%
# Llamadas a la función calcular_estadisticas_heteroatomos para base de datos de DrugBank
tabla3_drugbank = calcular_estadisticas_heteroatomos(fgs_drugbank)
tabla3_drugbank
# Out:
#    O FGs (bin) / mol  Frac O FGs (un)  N FGs (bin) / mol  Frac N FGs (un)  \
# 0            2.69755         1.963247           2.387443         1.644717
#
#    S FGs (bin) / mol  Frac S FGs (un)  P FGs (bin) / mol  Frac P FGs (un)  \
# 0           0.262634         0.237366           0.026034         0.022971
#
#    X FGs (bin) / mol  Frac X FGs (un)
# 0           0.586524          0.32925

# %%
# Llamadas a la función visualizar_coocurrencia_top_20_fgs para base de datos de DrugBank
visualizar_coocurrencia_top_20_fgs(fgs_drugbank)
